# %% [markdown]
# <a href="https://colab.research.google.com/github/plaban1981/DL_guided_Project/blob/main/Deep_Learning_Guided_Project_Higgs_Bosson_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Deep Learning Model For Binary Classification
#
# ![image.png](data:image/png;base64,...)
#
#
# ## Problem Statement
#
# The goal of the Higgs Boson Machine Learning Challenge is to explore the potential of advanced machine learning methods to improve the discovery significance of the experiment.

# %% [markdown]
# https://www.kaggle.com/c/higgs-boson
